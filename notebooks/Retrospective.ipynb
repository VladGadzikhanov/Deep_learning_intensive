# %%
import pandas as pd

# %%
df = pd.read_csv("../artifacts/2023-02-13_13-59-55/predictions.csv")

# %%
df[df["test_orig_targets"] != df["test_decoded_preds"]]
# Out:
#     test_orig_targets test_decoded_preds
# 7               f4fn2               f4f2
# 13              fcmem               fcme
# 28              77n6g               776g
# 31              w4nfx             w4nnfx
# 35              gny6b              gmy6b
# 41              pcm7f              pcn7f
# 42              8e32m             8e32nn
# 48              m4fd8               4fd8
# 51              nn6mg              nn6ng
# 57              3p67n               3p67
# 58              c7nn8               c7n8
# 63              bwmee             bwnnee
# 64              c2fb7              e2fb7
# 65              nm248             nnn248
# 72              cdcb3              edcb3
# 75              2mpnn             2nnpnn
# 76              x76mn              x76mm
# 82              pmd3w             pnnd3w
# 83              ggd7m             ggd7nm
# 88              ccn2x              ccm2x
# 89              ewnx8              ewmx8
# 95              243mm              243nn
# ...

# %% [markdown]
# Похоже на банальные "огрехи" модели. Пофиксить можно, поиграв с параметрами или подправив архитектуру(можно, к примеру, докинуть батчнорм после линейных слоев).
